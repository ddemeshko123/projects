# %%
import numpy as np
import cupy as cp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\cupy\__init__.py:16
#      15 try:
# ---> 16     with _warnings.catch_warnings():
#      17         _warnings.filterwarnings(
#      18             'ignore', category=ImportWarning,
#      19             message='can\'t resolve package from __spec__')
#
# ImportError: cannot import name '_core' from partially initialized module 'cupy' (most likely due to a circular import) (C:\Users\User\anaconda3\lib\site-packages\cupy\__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 import numpy as np
# ----> 2 import cupy as cp
#
# File ~\anaconda3\lib\site-packages\cupy\__init__.py:37
#      21 except ImportError as e:
# ...

# %%
# !nvcc --version
# Out:
# "nvcc" не является внутренней или внешней
# командой, исполняемой программой или пакетным файлом.

# %%
# !pip install cupy-cuda101
# Out:
# ...
#      ---------------------------------------- 0.0/43.1 MB ? eta -:--:--
#      ---------------------------------------- 0.1/43.1 MB 1.1 MB/s eta 0:00:40
#      ---------------------------------------- 0.2/43.1 MB 2.2 MB/s eta 0:00:20
#      ---------------------------------------- 0.4/43.1 MB 2.5 MB/s eta 0:00:17
#       --------------------------------------- 0.6/43.1 MB 3.3 MB/s eta 0:00:13
#       --------------------------------------- 1.0/43.1 MB 4.4 MB/s eta 0:00:10
#      - -------------------------------------- 1.3/43.1 MB 4.3 MB/s eta 0:00:10
#      - -------------------------------------- 2.1/43.1 MB 6.3 MB/s eta 0:00:07
#      - -------------------------------------- 2.1/43.1 MB 6.3 MB/s eta 0:00:07
#      - -------------------------------------- 2.1/43.1 MB 6.3 MB/s eta 0:00:07
#      -- ------------------------------------- 2.7/43.1 MB 5.6 MB/s eta 0:00:08
#      -- ------------------------------------- 3.1/43.1 MB 6.5 MB/s eta 0:00:07
# ...
